# %%
from pathlib import Path
import json

# %%
data_path = Path('data')
assembly_folders = [folder for folder in data_path.iterdir() if folder.is_dir()]

# %%
import random
indices = random.sample(range(len(assembly_folders)), 10)

# %%
from label_mesh import label_mesh

# %%
import time

# %%
start = time.time()
for i in range(10):
    assembly = str(assembly_folders[indices[i]])[5:]
    label_mesh(assembly, 'data_preprocess_step1')
end = time.time()
end - start
# Out:
# 3.0316050052642822

# %% [markdown]
# The Assembly Dataset contains 8,251 assemblies, and a total of 154,468 separate parts.

# %%
8251 * 3 / 10 / 60
# Out:
# 41.255
